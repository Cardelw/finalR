# %%
setwd('H:\\')

# %%
getwd()
# Out:
# [1] "H:/"

# %%
install.packages("rvest")
install.packages("httr")
install.packages("XML")
install.packages("htmltab")
# Out:
#   There is a binary version available but the source version is later:
#       binary source needs_compilation
# rvest  1.0.0  1.0.2             FALSE
# installing the source package 'rvest'
#   There is a binary version available but the source version is later:
#      binary source needs_compilation
# httr  1.4.2  1.4.3             FALSE
# installing the source package 'httr'
#
# Warning message:
# "package 'XML' is in use and will not be installed"
#   There is a binary version available but the source version is later:
#         binary source needs_compilation
# htmltab  0.8.1  0.8.2             FALSE
# installing the source package 'htmltab'

# %%
library(rvest)
library(httr)
library(XML)
library(htmltab)

# %%
 #Task 1
get_wiki_covid19_page <- function() {read_html("https://en.wikipedia.org/w/index.php?title=Template:COVID-19_testing_by_country")
                                       wiki_base_url <- "https://en.wikipedia.org/w/index.php/get"
                                      query_params <- list(name = "Template:COVID-19_testing_by_country")
                                      response <- GET(wiki_base_url, query=query_params)
                                      return(response)
                                      }
get_wiki_covid19_page
return(response)
# Out:
# function() {read_html("https://en.wikipedia.org/w/index.php?title=Template:COVID-19_testing_by_country")
#                                        wiki_base_url <- "https://en.wikipedia.org/w/index.php/get"
#                                       query_params <- list(name = "Template:COVID-19_testing_by_country")
#                                       response <- GET(wiki_base_url, query=query_params)
#                                       return(response)
#                                       }
# Response [https://en.wikipedia.org/w/index.php/get?name=Template%3ACOVID-19_testing_by_country]
#   Date: 2022-06-27 15:23
#   Status: 200
#   Content-Type: text/html; charset=UTF-8
#   Size: 34 kB
# <!DOCTYPE html>
# <html class="client-nojs" lang="en" dir="ltr">
# <head>
# <meta charset="UTF-8"/>
# <title>Get - Wikipedia</title>
# <script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames...
# ...

# %%
#Task 2
root_node <- read_html(response)
root_node
# Out:
# Error in read_html(response): object 'response' not found
# Traceback:
#
# 1. read_html(response)

# %%
table_node <- read_html(response, "table")
table_node
# Out:
# Error in read_html(response, "table"): object 'response' not found
# Traceback:
#
# 1. read_html(response, "table")

# %%
covid_table <- htmltab("https://en.wikipedia.org/w/index.php?title=Template:COVID-19_testing_by_country",1, rm_nodata_cols = F)

# %%
#Read the table node and convert it into a data frame, and print the data frame for review
data_frame <- data.frame(covid_table)
data_frame
# Out:
#     Country.or.region
# 2   Afghanistan
# 3   Albania
# 4   Algeria
# 5   Andorra
# 6   Angola
# 7   Antigua and Barbuda
# 8   Argentina
# 9   Armenia
# 10  Australia
# 11  Austria
# 12  Azerbaijan
# 13  Bahamas
# 14  Bahrain
# 15  Bangladesh
# 16  Barbados
# 17  Belarus
# 18  Belgium
# 19  Belize
# 20  Benin
# 21  Bhutan
# 22  Bolivia
# 23  Bosnia and Herzegovina
# 24  Botswana
# 25  Brazil
# 26  Brunei
# 27  Bulgaria
# 28  Burkina Faso
# 29  Burundi
# 30  Cambodia
# 31  Cameroon
# ... ...
# 145 Singapore
# ...
# 164 NA
# 165 NA
# 166 NA
# 167 NA
# 168 NA
# 169 NA
# 170 NA
# 171 NA
# 172 NA
# 173 NA
# ...

# %%
#TASK 3: Pre-process and export the extracted data frame # Print the summary of the data frame
str(data_frame)
# Out:
# 'data.frame':	173 obs. of  9 variables:
#  $ Country.or.region        : chr  "Afghanistan" "Albania" "Algeria" "Andorra" ...
#  $ Date                     : chr  "17 Dec 2020" "18 Feb 2021" "2 Nov 2020" "23 Feb 2022" ...
#  $ Tested                   : chr  "154,767" "428,654" "230,553" "300,307" ...
#  $ Units                    : chr  "samples" "samples" "samples" "samples" ...
#  $ Confirmed.cases.         : chr  "49,621" "96,838" "58,574" "37,958" ...
#  $ Confirmedâ...tested..    : chr  "32.1" "22.6" "25.4" "12.6" ...
#  $ Testedâ...population..   : chr  "0.40" "15.0" "0.53" "387" ...
#  $ Confirmedâ...population..: chr  "0.13" "3.4" "0.13" "49.0" ...
#  $ Ref.                     : chr  NA NA NA NA ...

# %%
preprocess_covid_data_frame <- function(data_frame) {
 shape <- dim(data_frame)
# Remove the World row
data_frame<-data_frame[!(data_frame$`Country.or.region`=="World"),]
# Remove the last row
data_frame <- data_frame[1:172, ]
# We dont need the Units and Ref columns, so can be removed
data_frame["Ref."]<- NULL
data_frame["Units"]<- NULL
# Renaming the columns
names(data_frame)<- c("country", "date", "tested", "confirmed", "confirmed.tested.ratio", "tested.population.ratio", "confirmed.population.ratio")
# Convert column data types
data_frame$country<- as.factor(data_frame$country)
data_frame$date<- as.factor(data_frame$date)
data_frame$tested<- as.numeric(gsub(",","",data_frame$tested))
data_frame$confirmed<- as.numeric(gsub(",","",data_frame$confirmed))
data_frame$'confirmed.tested.ratio' <- as.numeric(gsub(",","",data_frame$`confirmed.tested.ratio`))
data_frame$'tested.population.ratio' <- as.numeric(gsub(",","",data_frame$`tested.population.ratio`))
data_frame$'confirmed.population.ratio' <- as.numeric(gsub(",","",data_frame$`confirmed.population.ratio`))
return(data_frame)
    }

# %%
#Call the preprocess_covid_data_frame function # call `preprocess_covid_data_frame` function and assign it to a new data frame
#preprocess_covid_data_frame

# %%
#Get the summary of the processed data frame again # Print the summary of the processed data frame again # Export the data frame to a csv file
str(data_frame)
write.csv(data_frame,"C:\\Users\\CardelW\\Documents\\R_course\\covid_data.csv", row.names = FALSE)
# Out:
# 'data.frame':	173 obs. of  9 variables:
#  $ Country.or.region        : chr  "Afghanistan" "Albania" "Algeria" "Andorra" ...
#  $ Date                     : chr  "17 Dec 2020" "18 Feb 2021" "2 Nov 2020" "23 Feb 2022" ...
#  $ Tested                   : chr  "154,767" "428,654" "230,553" "300,307" ...
#  $ Units                    : chr  "samples" "samples" "samples" "samples" ...
#  $ Confirmed.cases.         : chr  "49,621" "96,838" "58,574" "37,958" ...
#  $ Confirmedâ...tested..    : chr  "32.1" "22.6" "25.4" "12.6" ...
#  $ Testedâ...population..   : chr  "0.40" "15.0" "0.53" "387" ...
#  $ Confirmedâ...population..: chr  "0.13" "3.4" "0.13" "49.0" ...
#  $ Ref.                     : chr  NA NA NA NA ...

# %%
# Get working directory
wd <- getwd()
# Get exported
file_path <- paste(wd, sep="", "/covid_data.csv")
# File path
print(file_path)
file.exists(file_path)
# Out:
# [1] "C:/Users/CardelW/covid_data.csv"
# [1] TRUE

# %%
## Download a sample csv file
covid_csv_file <- download.file("https://cf-coursesdata.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/dataset/covid.csv", destfile="covid.csv")
covid_data_frame_csv <- read.csv("covid.csv", header=TRUE, sep=",")
# Out:
# Warning message in download.file("https://cf-coursesdata.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/dataset/covid.csv", :
# "cannot open URL 'https://cf-coursesdata.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/dataset/covid.csv': HTTP status was '404 Not Found'"
# Error in download.file("https://cf-coursesdata.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/dataset/covid.csv", : cannot open URL 'https://cf-coursesdata.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/dataset/covid.csv'
# Traceback:
#
# 1. download.file("https://cf-coursesdata.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-RP0101EN-Coursera/v2/dataset/covid.csv",
#  .     destfile = "covid.csv")

# %%
data_frame <- read.csv(file = 'C:\\Users\\CardelW\\Documents\\R_course\\covid_data.csv')
head(data_frame)
# Out:
#   Country.or.region   Date        Tested  Units   Confirmed.cases.
# 1 Afghanistan         17 Dec 2020 154,767 samples 49,621
# 2 Albania             18 Feb 2021 428,654 samples 96,838
# 3 Algeria             2 Nov 2020  230,553 samples 58,574
# 4 Andorra             23 Feb 2022 300,307 samples 37,958
# 5 Angola              2 Feb 2021  399,228 samples 20,981
# 6 Antigua and Barbuda 6 Mar 2021  15,268  samples 832
#   Confirmedâ...tested.. Testedâ...population.. Confirmedâ...population.. Ref.
# 1 32.1                  0.40                   0.13                      NA
# 2 22.6                  15.0                   3.4                       NA
# 3 25.4                  0.53                   0.13                      NA
# 4 12.6                  387                    49.0                      NA
# 5 5.3                   1.3                    0.067                     NA
# 6 5.4                   15.9                   0.86                      NA

# %%
#getting a '404 Not Found' when I try to download from link provided. I made a local csv file to circumvent this.

#TASK 4: Get a subset of the extracted data frame
# Read covid_data_frame_csv from the csv file
data_frame <- read.csv(file = 'C:\\Users\\CardelW\\Downloads\\covid_data.csv')

# Get the 5th to 10th rows, with two "country" "confirmed" columns
task4 <- data_frame[5:10, c("Country", "confirmed")]
return(task4)
# Out:
#    Country              confirmed
# 5   Angola                20981
# 6   Antigua and Barbuda     832
# 7   Argentina           9060495
# 8   Armenia              422963
# 9   Australia           7568100
# 10  Austria             4342311

# %%
#TASK 5: Calculate worldwide COVID testing positive ratio 
#Get the total confirmed cases worldwide 
confirmed_world <- sum(data_frame$confirmed)
return(confirmed_world)

#Get the total tested cases worldwide
tested_world <- sum(data_frame$Tested) 
return(tested_world)

#Get the positive ratio (confirmed / tested) 
positive_ratio_world <- confirmed_world/tested_world 
return(positive_ratio_world)
# Out:
# [1] 336555914
# [1] 4475926613
# [1] 0.07519246

# %%
#TASK 6: Get a country list which reported their testing data
# Get the `country` column
# Check its class (should be Factor)
countries <- data_frame[, 1]
class(countries)
# Out:
# [1] "factor"

# %%
# Convert the country column into character so that you can easily sort them
countries <- as.character(countries)
class(countries)
# Out:
# [1] "character"

# %%
# Sort the countries AtoZ
sorted <- sort(countries)
#print (sorted)

# %%
# Sort the countries ZtoA
# Print the sorted ZtoA list
sortedztoa <- sort(countries, decreasing=TRUE)
print(sortedztoa)
# Out:
#   [1] " Zimbabwe"               " Zambia"
#   [3] " Vietnam"                " Venezuela"
#   [5] " Uzbekistan"             " Uruguay"
#   [7] " United States"          " United Kingdom"
#   [9] " United Arab Emirates"   " Ukraine"
#  [11] " Uganda"                 " Turkey"
#  [13] " Tunisia"                " Trinidad and Tobago"
#  [15] " Togo"                   " Thailand"
#  [17] " Tanzania"               " Taiwan[m]"
#  [19] " Switzerland[l]"         " Sweden"
#  [21] " Sudan"                  " Sri Lanka"
#  [23] " Spain"                  " South Sudan"
#  [25] " South Korea"            " South Africa"
#  [27] " Slovenia"               " Slovakia"
#  [29] " Singapore"              " Serbia"
#  [31] " Senegal"                " Saudi Arabia"
#  [33] " San Marino"             " Saint Vincent"
#  [35] " Saint Lucia"            " Saint Kitts and Nevis"
#  [37] " Rwanda"                 " Russia"
#  [39] " Romania"                " Qatar"
#  [41] " Portugal"               " Poland"
# ...

# %%
#TASK 7: Identify countries names with a specific pattern
# Use a regular expression `United.+` to find matches
# Print the matched country names
matches <- regexpr("United.+", countries)
regmatches(countries, matches)
# Out:
# [1] "United Arab Emirates" "United Kingdom"       "United States"

# %%
#TASK 8: Pick two countries you are interested, and then review their testing data
# Select a subset (should be only one row) of data frame based on a selected country name and columns

#selected <- data_frame["Country"] = "Jamaica"
#selected

# Get the selected row(s)
#jamaica <- data_frame[selected, ]
jamaica <- data_frame[81, ]
jamaica
# Out:
#    Country  Date       Tested  confirmed confirmed.tested.ratio
# 81  Jamaica 06/09/2022 1109127 139918    12.6
#    tested.population.ratio confirmed.population.ratio
# 81 40.7                    5.1

# %%
#TASK 8: Pick two countries you are interested, and then review their testing data
# Select a subset (should be only one row) of data frame based on a selected country name and columns
singapore <- data_frame[144, ]
singapore
# Out:
#     Country    Date       Tested   confirmed confirmed.tested.ratio
# 144  Singapore 08/03/2021 16206203 65315     0.4
#     tested.population.ratio confirmed.population.ratio
# 144 284                     1.1

# %%
#TASK 9: Compare which one of the selected countries has a larger ratio of confirmed cases to population
# Use if-else statement
jamaica_cpr <- jamaica[1,7]
singapore_cpr <- singapore[1,7]

 if (jamaica_cpr>singapore_cpr) {
 print('Jamaica')
 } else {
 print('Singapore')
 }
# Out:
# [1] "Jamaica"

# %%
#The goal of task 10 is to find out which countries have the confirmed to population ratio less than 1%, it may indicate the risk of those countries are relatively low
# Get a subset of any countries with `confirmed.population.ratio` less than the threshold

countries_cpr <- data_frame[, c("Country", "confirmed.population.ratio")]
LowCpr <- subset(countries_cpr ,confirmed.population.ratio<1)
return(LowCpr)
# Out:
#     Country              confirmed.population.ratio
# 1    Afghanistan         0.13000
# 3    Algeria             0.13000
# 5    Angola              0.06700
# 6    Antigua and Barbuda 0.86000
# 14   Bangladesh          0.70000
# 19   Benin               0.06700
# 25   Brunei              0.07400
# 27   Burkina Faso        0.05800
# 28   Burundi             0.00740
# 29   Cambodia            0.48000
# 30   Cameroon            0.12000
# 32   Chad                0.02900
# 34   China[c]            0.00610
# 45   DR Congo            0.02900
# 47   Egypt               0.28000
# 52   Ethiopia            0.24000
# 57   Gabon               0.08200
# 58   Gambia              0.21000
# 61   Ghana               0.31000
# 64   Grenada             0.14000
# 66   Guinea              0.19000
# 67   Guinea-Bissau       0.44000
# 69   Haiti               0.27000
# 80   Ivory Coast         0.13000
# 82   Japan               0.34000
# 85   Kenya               0.23000
# 89   Laos                0.00063
# ...
